# %% [markdown]
# Importing Liabriaries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.stats import skew

# %% [markdown]
# Loading the data set into the data frame

# %%
df=pd.read_csv('train.csv')
df.head(10)
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000001  P00069042      F   0-17          10             A
# 1  1000001  P00248942      F   0-17          10             A
# 2  1000001  P00087842      F   0-17          10             A
# 3  1000001  P00085442      F   0-17          10             A
# 4  1000002  P00285442      M    55+          16             C
# 5  1000003  P00193542      M  26-35          15             A
# 6  1000004  P00184942      M  46-50           7             B
# 7  1000004  P00346142      M  46-50           7             B
# 8  1000004   P0097242      M  46-50           7             B
# 9  1000005  P00274942      M  26-35          20             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
# 5                          3               0                   1
# 6                          2               1                   1
# 7                          2               1                   1
# 8                          2               1                   1
# 9                          1               1                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# 2                 NaN                 NaN      1422
# 3                14.0                 NaN      1057
# 4                 NaN                 NaN      7969
# 5                 2.0                 NaN     15227
# 6                 8.0                17.0     19215
# 7                15.0                 NaN     15854
# 8                16.0                 NaN     15686
# 9                 NaN                 NaN      7871

# %% [markdown]
# Displaying the No of rows and the colums in the dataset

# %%
df.shape
# Out:
# (550068, 12)

# %%
df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  5.500680e+05  550068.000000   550068.000000       550068.000000
# mean   1.003029e+06       8.076707        0.409653            5.404270
# std    1.727592e+03       6.522660        0.491770            3.936211
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001516e+06       2.000000        0.000000            1.000000
# 50%    1.003077e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       376430.000000       166821.000000  550068.000000
# mean             9.842329           12.668243    9263.968713
# std              5.086590            4.125338    5023.065394
# min              2.000000            3.000000      12.000000
# 25%              5.000000            9.000000    5823.000000
# 50%              9.000000           14.000000    8047.000000
# 75%             15.000000           16.000000   12054.000000
# max             18.000000           18.000000   23961.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 50.4+ MB

# %%
df.apply(lambda x: len(x.unique()))
# Out:
# User_ID                        5891
# Product_ID                     3631
# Gender                            2
# Age                               7
# Occupation                       21
# City_Category                     3
# Stay_In_Current_City_Years        5
# Marital_Status                    2
# Product_Category_1               20
# Product_Category_2               18
# Product_Category_3               16
# Purchase                      18105
# dtype: int64

# %%
df['Purchase'].skew()
# Out:
# 0.6001400037087128

# %%
sns.boxplot(x=df['Purchase'])
# Out:
# <AxesSubplot:xlabel='Purchase'>

# %%
sns.distplot(df['Purchase'])
# Out:
# E:\day4\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Purchase', ylabel='Density'>

# %%
df['Occupation'].skew()
# Out:
# 0.40014010986184784

# %%
sns.boxplot(x=df['Occupation'])
# Out:
# <AxesSubplot:xlabel='Occupation'>

# %%
sns.distplot(df['Occupation'])
# Out:
# E:\day4\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Occupation', ylabel='Density'>

# %%
df['Marital_Status'].skew()
# Out:
# 0.3674372854404167

# %%
sns.boxplot(x=df['Marital_Status'])
# Out:
# <AxesSubplot:xlabel='Marital_Status'>

# %%
sns.distplot(df['Marital_Status'])
# Out:
# E:\day4\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Marital_Status', ylabel='Density'>

# %%
df['Product_Category_1'].skew()
# Out:
# 1.0257349338538029

# %%
sns.boxplot(x=df['Product_Category_1'])
# Out:
# <AxesSubplot:xlabel='Product_Category_1'>

# %%
sns.distplot(df['Product_Category_1'])
# Out:
# E:\day4\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Product_Category_1', ylabel='Density'>

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(13,7))
sns.distplot(df['Purchase'],bins=25)
# Out:
# E:\day4\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Purchase', ylabel='Density'>

# %% [markdown]
# Exploriatory Data Analysis

# %%
sns.countplot(df['Gender'])
# Out:
# E:\day4\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.countplot(df['Marital_Status'])
# Out:
# <AxesSubplot:xlabel='Marital_Status', ylabel='count'>

# %%
sns.countplot(df['Marital_Status'])
# Out:
# E:\day4\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Marital_Status', ylabel='count'>

# %%
sns.countplot(df['Occupation'])
# Out:
# E:\day4\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Occupation', ylabel='count'>

# %%
sns.countplot(df['Product_Category_1'])
# Out:
# E:\day4\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Product_Category_1', ylabel='count'>

# %%
sns.countplot(df['Product_Category_2'])
# Out:
# E:\day4\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Product_Category_2', ylabel='count'>

# %%
sns.countplot(df['Product_Category_3'])
# Out:
# E:\day4\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Product_Category_3', ylabel='count'>

# %%
sns.countplot(df['City_Category'])
# Out:
# E:\day4\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(df['Stay_In_Current_City_Years'])
# Out:
# E:\day4\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
occupation_plot=df.pivot_table(index='Occupation',values='Purchase',aggfunc=np.mean)
occupation_plot.plot(kind='bar',figsize=(13,7))
plt.xlabel('Occupation')
plt.ylabel("Purchase")
plt.title("Occupation and Purchase Analysis")
plt.xticks(rotation=0)
plt.show()

# %%
Age_plot=df.pivot_table(index='Age',values='Purchase',aggfunc=np.mean)
Age_plot.plot(kind='bar',figsize=(13,7))
plt.xlabel('Age')
plt.ylabel("Purchase")
plt.title("Age and Purchase Analysis")
plt.xticks(rotation=0)
plt.show()

# %%
Gender_plot=df.pivot_table(index='Gender',values='Purchase',aggfunc=np.mean)
Gender_plot.plot(kind='bar',figsize=(13,7))
plt.xlabel('Gender')
plt.ylabel("Purchase")
plt.title("Gender and Purchase Analysis")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# preprocessing the dataset

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %% [markdown]
# Handling the null values

# %%
df['Product_Category_2']=df['Product_Category_2'].fillna(9.84).astype("float32")

# %%
df['Product_Category_3']=df['Product_Category_3'].fillna(12.66).astype("float32")

# %%
df.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Purchase                      0
# dtype: int64

# %%
df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  5.500680e+05  550068.000000   550068.000000       550068.000000
# mean   1.003029e+06       8.076707        0.409653            5.404270
# std    1.727592e+03       6.522660        0.491770            3.936211
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001516e+06       2.000000        0.000000            1.000000
# 50%    1.003077e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       550068.000000       550068.000000  550068.000000
# mean             9.844081           12.633951    9263.968713
# std              4.209368            2.271366    5023.065394
# min              2.000000            3.000000      12.000000
# 25%              8.000000           12.660000    5823.000000
# 50%              9.840000           12.660000    8047.000000
# 75%             14.000000           12.660000   12054.000000
# max             18.000000           18.000000   23961.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          550068 non-null  float32
#  10  Product_Category_3          550068 non-null  float32
#  11  Purchase                    550068 non-null  int64
# dtypes: float32(2), int64(5), object(5)
# memory usage: 46.2+ MB

# %%
df.head(10)
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000001  P00069042      F   0-17          10             A
# 1  1000001  P00248942      F   0-17          10             A
# 2  1000001  P00087842      F   0-17          10             A
# 3  1000001  P00085442      F   0-17          10             A
# 4  1000002  P00285442      M    55+          16             C
# 5  1000003  P00193542      M  26-35          15             A
# 6  1000004  P00184942      M  46-50           7             B
# 7  1000004  P00346142      M  46-50           7             B
# 8  1000004   P0097242      M  46-50           7             B
# 9  1000005  P00274942      M  26-35          20             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
# 5                          3               0                   1
# 6                          2               1                   1
# 7                          2               1                   1
# 8                          2               1                   1
# 9                          1               1                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                9.84               12.66      8370
# 1                6.00               14.00     15200
# 2                9.84               12.66      1422
# 3               14.00               12.66      1057
# 4                9.84               12.66      7969
# 5                2.00               12.66     15227
# 6                8.00               17.00     19215
# 7               15.00               12.66     15854
# 8               16.00               12.66     15686
# 9                9.84               12.66      7871

# %% [markdown]
# Changing the categorical values into the numeric values with the help of label encoding

# %%
cols=['Gender','Age','City_Category','Stay_In_Current_City_Years']
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for col in cols:
    df[col] =le.fit_transform(df[col])
df.head(10)
# Out:
#    User_ID Product_ID  Gender  Age  Occupation  City_Category  \
# 0  1000001  P00069042       0    0          10              0
# 1  1000001  P00248942       0    0          10              0
# 2  1000001  P00087842       0    0          10              0
# 3  1000001  P00085442       0    0          10              0
# 4  1000002  P00285442       1    6          16              2
# 5  1000003  P00193542       1    2          15              0
# 6  1000004  P00184942       1    4           7              1
# 7  1000004  P00346142       1    4           7              1
# 8  1000004   P0097242       1    4           7              1
# 9  1000005  P00274942       1    2          20              0
#
#    Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                           2               0                   3
# 1                           2               0                   1
# 2                           2               0                  12
# 3                           2               0                  12
# 4                           4               0                   8
# 5                           3               0                   1
# 6                           2               1                   1
# 7                           2               1                   1
# 8                           2               1                   1
# 9                           1               1                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# 2                 NaN                 NaN      1422
# 3                14.0                 NaN      1057
# 4                 NaN                 NaN      7969
# 5                 2.0                 NaN     15227
# 6                 8.0                17.0     19215
# 7                15.0                 NaN     15854
# 8                16.0                 NaN     15686
# 9                 NaN                 NaN      7871

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  int32
#  3   Age                         550068 non-null  int32
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  int32
#  6   Stay_In_Current_City_Years  550068 non-null  int32
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          550068 non-null  float32
#  10  Product_Category_3          550068 non-null  float32
#  11  Purchase                    550068 non-null  int64
# dtypes: float32(2), int32(4), int64(5), object(1)
# memory usage: 37.8+ MB

# %% [markdown]
# Correlation Matrix

# %% [markdown]
# To check the relationship between the various columns with respect to target variable

# %%
corr=df.corr()
plt.figure(figsize=(14,7))
sns.heatmap(corr,annot=True,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
X=df.drop(columns=['User_ID','Product_ID','Purchase'])
Y=df['Purchase']

# %% [markdown]
# Train Test split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=7)

# %%
from sklearn.ensemble import RandomForestRegressor
rfc=RandomForestRegressor(random_state=7)
rfc.fit(X_train,Y_train)
Y_pred = rfc.predict(X_test)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
cv_score=cross_val_score(rfc,X,Y,scoring='neg_mean_squared_error',cv=5)
cv_score=np.abs(np.mean(cv_score))
print('Results')
print("MSE:",np.sqrt(mean_squared_error(Y_test,Y_pred)))
print("CV score:",np.sqrt(cv_score))
# Out:
# Results
# MSE: 3045.771709684072
# CV score: 3051.6144930381897

# %%
from sklearn.metrics import r2_score

# %%
r2_score(Y_test,Y_pred)
# Out:
# 0.6326211695158892

# %%
from sklearn.tree import DecisionTreeRegressor
dtc=DecisionTreeRegressor()
dtc.fit(X_train,Y_train)
Y_pred = dtc.predict(X_test)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
cv_score=cross_val_score(dtc,X,Y,scoring='neg_mean_squared_error',cv=5)
cv_score=np.abs(np.mean(cv_score))
print('Results')
print("MSE:",np.sqrt(mean_squared_error(Y_test,Y_pred)))
print("CV score:",np.sqrt(cv_score))
# Out:
# Results
# MSE: 3349.108342912659
# CV score: 3338.256665115956

# %%
from sklearn.metrics import r2_score

# %%
r2_score(Y_test,Y_pred)
# Out:
# 0.5554441701223072

# %%
from sklearn.ensemble import GradientBoostingRegressor
xgb=GradientBoostingRegressor(n_estimators=100,learning_rate=0.1,random_state=7)
xgb.fit(X_train,Y_train)
Y_pred = xgb.predict(X_test)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
cv_score=cross_val_score(xgb,X,Y,scoring='neg_mean_squared_error',cv=5)
cv_score=np.abs(np.mean(cv_score))
print('Results')
print("MSE:",np.sqrt(mean_squared_error(Y_test,Y_pred)))
print("CV score:",np.sqrt(cv_score))
# Out:
# Results
# MSE: 2981.0276533542356
# CV score: 2993.0048243472515

# %% [markdown]
# Fine tunning of the Randomn Forest regressor

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %%
param_grid = { 
    'n_estimators': [100,200],
    'max_depth' : [5,10,15],
    'criterion' :['gini']
}

# %%
CV_rfc = GridSearchCV(estimator=rfc, param_grid=param_grid,\
                      cv= 2, verbose=1)

# %%
CV_rfc.fit(X_train, Y_train)
# Out:
# Fitting 2 folds for each of 6 candidates, totalling 12 fits
# E:\day4\anaconda\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "E:\day4\anaconda\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\ensemble\_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "E:\day4\anaconda\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "E:\day4\anaconda\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "E:\day4\anaconda\lib\site-packages\sklearn\tree\_classes.py", line 350, in fit
#     criterion = CRITERIA_REG[self.criterion](self.n_outputs_,
# KeyError: 'gini'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# E:\day4\anaconda\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "E:\day4\anaconda\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\ensemble\_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "E:\day4\anaconda\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "E:\day4\anaconda\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "E:\day4\anaconda\lib\site-packages\sklearn\tree\_classes.py", line 350, in fit
#     criterion = CRITERIA_REG[self.criterion](self.n_outputs_,
# KeyError: 'gini'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# E:\day4\anaconda\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "E:\day4\anaconda\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\ensemble\_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "E:\day4\anaconda\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "E:\day4\anaconda\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "E:\day4\anaconda\lib\site-packages\sklearn\tree\_classes.py", line 350, in fit
#     criterion = CRITERIA_REG[self.criterion](self.n_outputs_,
# KeyError: 'gini'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# E:\day4\anaconda\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "E:\day4\anaconda\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\ensemble\_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "E:\day4\anaconda\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "E:\day4\anaconda\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "E:\day4\anaconda\lib\site-packages\sklearn\tree\_classes.py", line 350, in fit
#     criterion = CRITERIA_REG[self.criterion](self.n_outputs_,
# KeyError: 'gini'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# E:\day4\anaconda\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "E:\day4\anaconda\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\ensemble\_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "E:\day4\anaconda\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "E:\day4\anaconda\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "E:\day4\anaconda\lib\site-packages\sklearn\tree\_classes.py", line 350, in fit
#     criterion = CRITERIA_REG[self.criterion](self.n_outputs_,
# KeyError: 'gini'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# E:\day4\anaconda\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "E:\day4\anaconda\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\ensemble\_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "E:\day4\anaconda\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "E:\day4\anaconda\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "E:\day4\anaconda\lib\site-packages\sklearn\tree\_classes.py", line 350, in fit
#     criterion = CRITERIA_REG[self.criterion](self.n_outputs_,
# KeyError: 'gini'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# E:\day4\anaconda\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "E:\day4\anaconda\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\ensemble\_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "E:\day4\anaconda\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "E:\day4\anaconda\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "E:\day4\anaconda\lib\site-packages\sklearn\tree\_classes.py", line 350, in fit
#     criterion = CRITERIA_REG[self.criterion](self.n_outputs_,
# KeyError: 'gini'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# E:\day4\anaconda\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "E:\day4\anaconda\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\ensemble\_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "E:\day4\anaconda\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "E:\day4\anaconda\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "E:\day4\anaconda\lib\site-packages\sklearn\tree\_classes.py", line 350, in fit
#     criterion = CRITERIA_REG[self.criterion](self.n_outputs_,
# KeyError: 'gini'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# E:\day4\anaconda\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "E:\day4\anaconda\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\ensemble\_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "E:\day4\anaconda\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "E:\day4\anaconda\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "E:\day4\anaconda\lib\site-packages\sklearn\tree\_classes.py", line 350, in fit
#     criterion = CRITERIA_REG[self.criterion](self.n_outputs_,
# KeyError: 'gini'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# E:\day4\anaconda\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "E:\day4\anaconda\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\ensemble\_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "E:\day4\anaconda\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "E:\day4\anaconda\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "E:\day4\anaconda\lib\site-packages\sklearn\tree\_classes.py", line 350, in fit
#     criterion = CRITERIA_REG[self.criterion](self.n_outputs_,
# KeyError: 'gini'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# E:\day4\anaconda\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "E:\day4\anaconda\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\ensemble\_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "E:\day4\anaconda\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "E:\day4\anaconda\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "E:\day4\anaconda\lib\site-packages\sklearn\tree\_classes.py", line 350, in fit
#     criterion = CRITERIA_REG[self.criterion](self.n_outputs_,
# KeyError: 'gini'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# E:\day4\anaconda\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "E:\day4\anaconda\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\ensemble\_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "E:\day4\anaconda\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "E:\day4\anaconda\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "E:\day4\anaconda\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "E:\day4\anaconda\lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "E:\day4\anaconda\lib\site-packages\sklearn\tree\_classes.py", line 350, in fit
#     criterion = CRITERIA_REG[self.criterion](self.n_outputs_,
# KeyError: 'gini'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# E:\day4\anaconda\lib\site-packages\sklearn\model_selection\_search.py:918: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan]
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-c9fa9160cd34> in <module>
# ----> 1 CV_rfc.fit(X_train, Y_train)
#
# E:\day4\anaconda\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# E:\day4\anaconda\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     878             refit_start_time = time.time()
#     879             if y is not None:
# --> 880                 self.best_estimator_.fit(X, y, **fit_params)
#     881             else:
#     882                 self.best_estimator_.fit(X, **fit_params)
#
# E:\day4\anaconda\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     385             # parallel_backend contexts set at a higher level,
#     386             # since correctness does not rely on using threads.
# --> 387             trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#     388                              **_joblib_parallel_args(prefer='threads'))(
#     389                 delayed(_parallel_build_trees)(
#
# E:\day4\anaconda\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1039             # remaining jobs.
#    1040             self._iterating = False
# -> 1041             if self.dispatch_one_batch(iterator):
#    1042                 self._iterating = self._original_iterator is not None
#    1043
#
# E:\day4\anaconda\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     857                 return False
#     858             else:
# --> 859                 self._dispatch(tasks)
#     860                 return True
#     861
#
# E:\day4\anaconda\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     775         with self._lock:
#     776             job_idx = len(self._jobs)
# --> 777             job = self._backend.apply_async(batch, callback=cb)
#     778             # A job can complete so quickly than its callback is
#     779             # called before we get here, causing self._jobs to
#
# E:\day4\anaconda\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# E:\day4\anaconda\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# E:\day4\anaconda\lib\site-packages\joblib\parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# E:\day4\anaconda\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# E:\day4\anaconda\lib\site-packages\sklearn\utils\fixes.py in __call__(self, *args, **kwargs)
#     220     def __call__(self, *args, **kwargs):
#     221         with config_context(**self.config):
# --> 222             return self.function(*args, **kwargs)
#
# E:\day4\anaconda\lib\site-packages\sklearn\ensemble\_forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     167                                                         indices=indices)
#     168
# --> 169         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     170     else:
#     171         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# E:\day4\anaconda\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1245         """
#    1246
# -> 1247         super().fit(
#    1248             X, y,
#    1249             sample_weight=sample_weight,
#
# E:\day4\anaconda\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     348                                                          self.n_classes_)
#     349             else:
# --> 350                 criterion = CRITERIA_REG[self.criterion](self.n_outputs_,
#     351                                                          n_samples)
#     352
#
# KeyError: 'gini'

# %%
print(CV_rfc.best_params_)
# Out:
# {'criterion': 'gini', 'max_depth': 5, 'n_estimators': 100}

# %%
from sklearn.ensemble import RandomForestRegressor
rfc=RandomForestRegressor(random_state=7,max_depth=5,n_estimators=100)
rfc.fit(X_train,Y_train)
Y_pred = rfc.predict(X_test)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
cv_score=cross_val_score(rfc,X,Y,scoring='neg_mean_squared_error',cv=5)
cv_score=np.abs(np.mean(cv_score))
print('Results')
print("MSE:",np.sqrt(mean_squared_error(Y_test,Y_pred)))
print("CV score:",np.sqrt(cv_score))
# Out:
# Results
# MSE: 3266.9083078497147
# CV score: 3424.175710673634

# %% [markdown]
# Fine tunning of the XG Boost Regressor

# %%
xgb.get_params().keys()
# Out:
# dict_keys(['alpha', 'ccp_alpha', 'criterion', 'init', 'learning_rate', 'loss', 'max_depth', 'max_features', 'max_leaf_nodes', 'min_impurity_decrease', 'min_impurity_split', 'min_samples_leaf', 'min_samples_split', 'min_weight_fraction_leaf', 'n_estimators', 'n_iter_no_change', 'random_state', 'subsample', 'tol', 'validation_fraction', 'verbose', 'warm_start'])

# %%
param_grid = { 
    'n_estimators': [1000,2000,2500],
     'max_depth' : [15,20,30],
    'n_iter_no_change' : [15,20,25],
    'learning_rate' : [0.1],
    'min_samples_split' : [20,30,35]
}

# %%
from sklearn.model_selection import GridSearchCV
CV_xgbc = GridSearchCV(estimator=xgb, param_grid=param_grid,\
                      cv= 2, verbose=2)

# %%
CV_xgbc.fit(X_train, Y_train)
# Out:
# Fitting 2 folds for each of 81 candidates, totalling 162 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-51a297691516> in <module>
# ----> 1 CV_xgbc.fit(X_train, Y_train)
#
# E:\day4\anaconda\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# E:\day4\anaconda\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     839                 return results
#     840
# --> 841             self._run_search(evaluate_candidates)
#     842
#     843             # multimetric is determined here because in the case of a callable
#
# E:\day4\anaconda\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1286     def _run_search(self, evaluate_candidates):
#    1287         """Search all candidates in param_grid"""
# -> 1288         evaluate_candidates(ParameterGrid(self.param_grid))
#    1289
#    1290
#
# E:\day4\anaconda\lib\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     793                               n_splits, n_candidates, n_candidates * n_splits))
#     794
# --> 795                 out = parallel(delayed(_fit_and_score)(clone(base_estimator),
#     796                                                        X, y,
#     797                                                        train=train, test=test,
#
# E:\day4\anaconda\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1039             # remaining jobs.
#    1040             self._iterating = False
# -> 1041             if self.dispatch_one_batch(iterator):
#    1042                 self._iterating = self._original_iterator is not None
#    1043
#
# E:\day4\anaconda\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     857                 return False
#     858             else:
# --> 859                 self._dispatch(tasks)
#     860                 return True
#     861
#
# E:\day4\anaconda\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     775         with self._lock:
#     776             job_idx = len(self._jobs)
# --> 777             job = self._backend.apply_async(batch, callback=cb)
#     778             # A job can complete so quickly than its callback is
#     779             # called before we get here, causing self._jobs to
#
# E:\day4\anaconda\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# E:\day4\anaconda\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# E:\day4\anaconda\lib\site-packages\joblib\parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# E:\day4\anaconda\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# E:\day4\anaconda\lib\site-packages\sklearn\utils\fixes.py in __call__(self, *args, **kwargs)
#     220     def __call__(self, *args, **kwargs):
#     221         with config_context(**self.config):
# --> 222             return self.function(*args, **kwargs)
#
# E:\day4\anaconda\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     591             estimator.fit(X_train, **fit_params)
#     592         else:
# --> 593             estimator.fit(X_train, y_train, **fit_params)
#     594
#     595     except Exception as e:
#
# E:\day4\anaconda\lib\site-packages\sklearn\ensemble\_gb.py in fit(self, X, y, sample_weight, monitor)
#     502
#     503         # fit the boosting stages
# --> 504         n_stages = self._fit_stages(
#     505             X, y, raw_predictions, sample_weight, self._rng, X_val, y_val,
#     506             sample_weight_val, begin_at_stage, monitor)
#
# E:\day4\anaconda\lib\site-packages\sklearn\ensemble\_gb.py in _fit_stages(self, X, y, raw_predictions, sample_weight, random_state, X_val, y_val, sample_weight_val, begin_at_stage, monitor)
#     559
#     560             # fit next stage of trees
# --> 561             raw_predictions = self._fit_stage(
#     562                 i, X, y, raw_predictions, sample_weight, sample_mask,
#     563                 random_state, X_csc, X_csr)
#
# E:\day4\anaconda\lib\site-packages\sklearn\ensemble\_gb.py in _fit_stage(self, i, X, y, raw_predictions, sample_weight, sample_mask, random_state, X_csc, X_csr)
#     212
#     213             X = X_csr if X_csr is not None else X
# --> 214             tree.fit(X, residual, sample_weight=sample_weight,
#     215                      check_input=False)
#     216
#
# E:\day4\anaconda\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1245         """
#    1246
# -> 1247         super().fit(
#    1248             X, y,
#    1249             sample_weight=sample_weight,
#
# E:\day4\anaconda\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     387                                            min_impurity_split)
#     388
# --> 389         builder.build(self.tree_, X, y, sample_weight)
#     390
#     391         if self.n_outputs_ == 1 and is_classifier(self):
#
# KeyboardInterrupt:

# %%
print(CV_xgbc.best_params_)
# Out:
# {'learning_rate': 0.1, 'max_depth': 15, 'min_samples_split': 35, 'n_estimators': 2500, 'n_iter_no_change': 15}

# %%
from sklearn.ensemble import GradientBoostingRegressor
xgb=GradientBoostingRegressor(learning_rate=0.1, max_depth= 15, min_samples_split= 35, n_estimators= 2500, n_iter_no_change= 15)
xgb.fit(X_train,Y_train)
Y_pred = xgb.predict(X_test)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
cv_score=cross_val_score(xgb,X,Y,scoring='neg_mean_squared_error',cv=5)
cv_score=np.abs(np.mean(cv_score))
print('Results')
print("MSE:",np.sqrt(mean_squared_error(Y_test,Y_pred)))
print("CV score:",np.sqrt(cv_score))
# Out:
# Results
# MSE: 2891.762137641182
# CV score: 2906.2578329144512

# %%
param_grid = { 
    'n_estimators': [1000,2000,2500],
     'max_depth' : [5],
    'n_iter_no_change' : [15,20,25],
    'learning_rate' : [0.1],
    'min_samples_split' : [5]
}

# %%
from sklearn.model_selection import GridSearchCV
CV_xgbc1 = GridSearchCV(estimator=xgb, param_grid=param_grid,\
                      cv= 2, verbose=2)

# %%
CV_xgbc1.fit(X_train, Y_train)
# Out:
# Fitting 2 folds for each of 9 candidates, totalling 18 fits
# [CV] END learning_rate=0.1, max_depth=5, min_samples_split=5, n_estimators=1000, n_iter_no_change=15; total time= 3.8min
# [CV] END learning_rate=0.1, max_depth=5, min_samples_split=5, n_estimators=1000, n_iter_no_change=15; total time= 2.6min
# [CV] END learning_rate=0.1, max_depth=5, min_samples_split=5, n_estimators=1000, n_iter_no_change=20; total time= 2.8min
# [CV] END learning_rate=0.1, max_depth=5, min_samples_split=5, n_estimators=1000, n_iter_no_change=20; total time= 2.4min
# [CV] END learning_rate=0.1, max_depth=5, min_samples_split=5, n_estimators=1000, n_iter_no_change=25; total time= 3.1min
# [CV] END learning_rate=0.1, max_depth=5, min_samples_split=5, n_estimators=1000, n_iter_no_change=25; total time= 2.5min
# [CV] END learning_rate=0.1, max_depth=5, min_samples_split=5, n_estimators=2000, n_iter_no_change=15; total time= 3.0min
# [CV] END learning_rate=0.1, max_depth=5, min_samples_split=5, n_estimators=2000, n_iter_no_change=15; total time= 2.3min
# [CV] END learning_rate=0.1, max_depth=5, min_samples_split=5, n_estimators=2000, n_iter_no_change=20; total time= 2.9min
# [CV] END learning_rate=0.1, max_depth=5, min_samples_split=5, n_estimators=2000, n_iter_no_change=20; total time= 2.5min
# [CV] END learning_rate=0.1, max_depth=5, min_samples_split=5, n_estimators=2000, n_iter_no_change=25; total time= 3.1min
# [CV] END learning_rate=0.1, max_depth=5, min_samples_split=5, n_estimators=2000, n_iter_no_change=25; total time= 2.5min
# [CV] END learning_rate=0.1, max_depth=5, min_samples_split=5, n_estimators=2500, n_iter_no_change=15; total time= 3.0min
# [CV] END learning_rate=0.1, max_depth=5, min_samples_split=5, n_estimators=2500, n_iter_no_change=15; total time= 2.4min
# [CV] END learning_rate=0.1, max_depth=5, min_samples_split=5, n_estimators=2500, n_iter_no_change=20; total time= 3.0min
# [CV] END learning_rate=0.1, max_depth=5, min_samples_split=5, n_estimators=2500, n_iter_no_change=20; total time= 2.6min
# [CV] END learning_rate=0.1, max_depth=5, min_samples_split=5, n_estimators=2500, n_iter_no_change=25; total time= 3.2min
# [CV] END learning_rate=0.1, max_depth=5, min_samples_split=5, n_estimators=2500, n_iter_no_change=25; total time= 2.3min
# GridSearchCV(cv=2, estimator=GradientBoostingRegressor(random_state=7),
#              param_grid={'learning_rate': [0.1], 'max_depth': [5],
#                          'min_samples_split': [5],
#                          'n_estimators': [1000, 2000, 2500],
#                          'n_iter_no_change': [15, 20, 25]},
#              verbose=2)

# %%
print(CV_xgbc1.best_params_)
# Out:
# {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_split': 5, 'n_estimators': 1000, 'n_iter_no_change': 25}

# %%
from sklearn.ensemble import GradientBoostingRegressor
xgb=GradientBoostingRegressor(learning_rate=0.1, max_depth= 5, min_samples_split= 5, n_estimators= 1000, n_iter_no_change= 25)
xgb.fit(X_train,Y_train)
Y_pred = xgb.predict(X_test)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
cv_score=cross_val_score(xgb,X,Y,scoring='neg_mean_squared_error',cv=5)
cv_score=np.abs(np.mean(cv_score))
print('Results')
print("RMSE:",np.sqrt(mean_squared_error(Y_test,Y_pred)))
print("CV score:",np.sqrt(cv_score))
# Out:
# Results
# MSE: 2869.7039908435927
# CV score: 2879.8838350175597

# %%
from sklearn.metrics import r2_score

# %%
r2_score(Y_test,Y_pred)
# Out:
# 0.6736917301581312

# %% [markdown]
# Building predictive system

# %%
input_data = (1,2,12,2,4,1,1,8,14)

#changing input data into numpy array
input_data_as_numpy_array = np.asarray(input_data)

#reshaping the array
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = xgb.predict(input_data_reshaped)
print(prediction)
# Out:
# [13476.2396241]
